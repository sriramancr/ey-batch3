# %% [markdown]
# # LangChain implementation

# %%
import os
from langchain_openai import ChatOpenAI

# %%
# Openai llm
# key = "sk-"
# llm = ChatOpenAI(api_key = key)

llm = ChatOpenAI()

# %%
print(llm)
# Out:
# output_version=None profile={'name': 'GPT-3.5-turbo', 'release_date': '2023-03-01', 'last_updated': '2023-11-06', 'open_weights': False, 'max_input_tokens': 16385, 'max_output_tokens': 4096, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': False, 'structured_output': False, 'attachment': False, 'temperature': True, 'image_url_inputs': False, 'pdf_inputs': False, 'pdf_tool_message': False, 'image_tool_message': False, 'tool_choice': True} client=<openai.resources.chat.completions.completions.Completions object at 0x000002639D19F750> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000263A2ECE050> root_client=<openai.OpenAI object at 0x000002639E728390> root_async_client=<openai.AsyncOpenAI object at 0x00000263A2ECEC90> model_kwargs={} openai_api_key=SecretStr('**********') openai_proxy=None stream_usage=True stream_chunk_timeout=120.0

# %%
# ******************************************
# 1) Simple LLM
# Description: Interfaces for language models
# *******************************************
def run(prompt):
    try:
    
        messages = [ ("system", "You are a helpful assistant good in giving information",),
                    ("human", prompt), ]
        
        response = llm.invoke(messages)
        # content = response
        # print(response.content)
    
    except Exception as e:
        response = "Exception from run()." + "\n" + str(e)
    
    return (response)

# %%
# 0-shot prompt
prompt = "Is time travel really popssible. Give 3 key points"
response = run(prompt)

# %%
print("Full Response")
print(response)

print()
# Contents
print("Contents ...")
print(response.content)
print()

# Token usage
print("Tokens Usage ...")
print(response.response_metadata["token_usage"])
# Out:
# Full Response
# content='1. Theoretical Physics: According to the theory of relativity developed by Albert Einstein, time dilation occurs when an object is moving close to the speed of light or in the presence of a strong gravitational field. This suggests that time travel may be possible under specific conditions.\n\n2. Wormholes: Some theories suggest that traversable wormholes could serve as shortcuts through spacetime, allowing for potential time travel between different points in time. However, the existence of such wormholes has not been proven, and their stability remains a major obstacle.\n\n3. Grandfather Paradox: One of the main paradoxes associated with time travel is the "grandfather paradox," which questions the implications of going back in time and potentially altering the past. This paradox raises significant concerns about the feasibility and consequences of time travel.\n\nIn conclusion, while there are intriguing theories and concepts related to time travel, its actual possibility remains a subject of debate and exploration in the realm of theoretical physics and science fiction.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 195, 'prompt_tokens': 33, 'total_tokens': 228, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DrLXZOnvpmBolGniWXWmkURnjvSSM', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019ed006-a005-7bf0-9132-073b93e84376-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 33, 'output_tokens': 195, 'total_tokens': 228, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#
# Contents ...
# 1. Theoretical Physics: According to the theory of relativity developed by Albert Einstein, time dilation occurs when an object is moving close to the speed of light or in the presence of a strong gravitational field. This suggests that time travel may be possible under specific conditions.
#
# 2. Wormholes: Some theories suggest that traversable wormholes could serve as shortcuts through spacetime, allowing for potential time travel between different points in time. However, the existence of such wormholes has not been proven, and their stability remains a major obstacle.
#
# 3. Grandfather Paradox: One of the main paradoxes associated with time travel is the "grandfather paradox," which questions the implications of going back in time and potentially altering the past. This paradox raises significant concerns about the feasibility and consequences of time travel.
#
# In conclusion, while there are intriguing theories and concepts related to time travel, its actual possibility remains a subject of debate and exploration in the realm of theoretical physics and science fiction.
#
# Tokens Usage ...
# {'completion_tokens': 195, 'prompt_tokens': 33, 'total_tokens': 228, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}

# %%
print(response.content)
# Out:
# Certainly! One historical fact about the Ellora Caves is that they were excavated over a period of five centuries, from the 6th to the 11th century. These caves in Maharashtra, India, are a UNESCO World Heritage Site and showcase a unique blend of Hindu, Buddhist, and Jain monuments. The Ellora Caves are known for their remarkable rock-cut architecture and intricate sculptures, making them a significant historical and cultural site in India.

# %%
# 1-shot prompt
prompt = '''
Generate a short, enticing product description for a 'WhisFlow' smart air purifier, 
highlighting its quiet operation and intelligent air quality sensing.

Start with the text 'Introducing the WhisperFlow humidifier....'
'''
response = run(prompt)
print(response.content)

# %% [markdown]
# # --------------------------------------------------------
# # 2) Parameterized templates / Placeholder-based templates
# # --------------------------------------------------------
#
# '''
# Use LangChain PromptTemplate when:
#     Building AI applications
#     Chains/agents
#     Reusable workflows
#     Multi-step pipelines
#     Production systems
#     Multi-agent orchestration
# '''

# %%
# *************************************************
#   2.1) Component: Prompt Templates
#   Build templates to optimize LLM queries / prompts
# *************************************************

# from langchain.prompts import PromptTemplate # old version
from langchain_core.prompts import PromptTemplate # recent

# 1)
# topic = "temples and architecture" # gives the full answer

# topic = "" # asks user to complete response
topic = "exploring caves"

try:
    pt = PromptTemplate(input_variables=["topic"], 
                        template="what are the top 5 destinations for people who love {topic}?" )

    # print(pt)
    prompt = pt.format(topic=topic)
    
    # prompt = pt.format()
    # Python f formatting will not identify if 'topic' is missing

    print(prompt)
    response = run(prompt)
    print(response.content)

except Exception as e:
    print("Exception : " + str(e))
# Out:
# what are the top 5 destinations for people who love exploring caves?
# 1. Mammoth Cave National Park in Kentucky, USA - Known as the world's longest known cave system, Mammoth Cave offers a variety of cave tours for all levels of experience.
#
# 2. Carlsbad Caverns National Park in New Mexico, USA - Home to over 100 limestone caves, Carlsbad Caverns is famous for its stunning underground formations and bat flights.
#
# 3. Waitomo Glowworm Caves in New Zealand - These unique caves are home to thousands of glowworms that create a magical glow in the darkness, making it a popular tourist attraction.
#
# 4. Postojna Cave in Slovenia - One of the largest cave systems in Europe, Postojna Cave offers guided tours through its fascinating underground world of stalactites and stalagmites.
#
# 5. Phong Nha-Ke Bang National Park in Vietnam - This UNESCO World Heritage Site is home to the largest cave in the world, Son Doong Cave, as well as many other incredible caves waiting to be explored.

# %%
# 2) 2 parameters
temp = "tell me a {p1} fact about {p2}"
pt = PromptTemplate.from_template(temp)

print(pt)
# Out:
# input_variables=['p1', 'p2'] input_types={} partial_variables={} template='tell me a {p1} fact about {p2}'

# %%
prompt = pt.format(p1="historical",p2="ellora caves")
print(prompt)
print()

response = run(prompt)
print(response.content)
# Out:
# tell me a historical fact about ellora caves
#
# Certainly! One historical fact about the Ellora Caves is that they were excavated over a period of five centuries, from the 6th to the 11th century. These caves in Maharashtra, India, are a UNESCO World Heritage Site and showcase a unique blend of Hindu, Buddhist, and Jain monuments. The Ellora Caves are known for their remarkable rock-cut architecture and intricate sculptures, making them a significant historical and cultural site in India.

# %%
# 3) 3 parameters
temp = "write a short note on {p1} and its impact on {p2} and {p3}"
pt = PromptTemplate.from_template(temp)
prompt = pt.format(p1="social media",p2="children",p3="senior citizens")

print(prompt)
response = run(prompt)
print(response.content)

# %% [markdown]
# # ====================================================
# # 3) Component: Chains
# # Combine LLMs and Prompt templates to build workflows
# # ====================================================

# %%
# ***********************************************************************************************************
# example 3.1 
# simple chain without any input parameter and output parser
# # A basic single-step chain that takes a user query, formats it using a prompt, and gets an answer from the LLM.
# ***********************************************************************************************************

from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
# i) Create the LLM
# llm = ChatOpenAI()

# ii) Create the Prompt
qry = ''' 
    A company is planning to conduct a training program on AI to its leaders.
    Suggest a suitable program name in about 5 words.
    '''
prompt = PromptTemplate.from_template(qry)
print(prompt)
# Out:
# input_variables=[] input_types={} partial_variables={} template=' \n    A company is planning to conduct a training program on AI to its leaders.\n    Suggest a suitable program name in about 5 words.\n    '

# %%
# iii) Create the LLM Chain
# new method
# this method is called LCEL (LangChain Expression Language)
# Connect AI components such as prompts, models, data retrievers, and parsers using a simple, chainable syntax with the pipe | operator, enabling smooth data flow from one component to the next.

# It is designed to simplify the creation of complex AI pipelines while keeping code clean, modular, and readable.

chain = prompt | llm

# %%
# iv) Run it
result = chain.invoke({})
print(result.content)
# Out:
# "AI Leaders Mastery Training Program"

# %% [markdown]
# # ***********************************************************************************************************
# # example 3.2
# # simple chain with input parameter and an output parser
# # A basic single-step chain that takes a user query, formats it using a prompt,
# # gets an answer from the LLM, formats the response
# # ***********************************************************************************************************

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
# i) Create the LLM
# llm = ChatOpenAI()

# ii) Create the Prompt
prompt = PromptTemplate(input_variables=["topic"], 
                        template="Explain in 3 bullet points the concept of {topic}" )

# %%
# iii) Create the LLM Chain
chain = prompt | llm | StrOutputParser()

# %%
# iv) Run it
topic = "Carbon Dating"

result = chain.invoke({"topic":topic})
print(result)
# Out:
# - Carbon dating is a method used by scientists to determine the age of organic materials by measuring the levels of carbon-14, a radioactive isotope of carbon, present in the sample.
# - Carbon dating works by comparing the ratio of carbon-14 to carbon-12 in the sample to known ratios in the atmosphere, which allows scientists to calculate how long it has been since the organism died.
# - This method is commonly used to date archaeological artifacts, fossils, and other organic materials up to around 50,000 years old, as carbon-14 has a half-life of about 5,730 years.

# %% [markdown]
# '''
# Use PromptTemplate when
# -----------------------
#     your prompt is basically one text block.
#     you have a single instruction
#     you do not need roles like system/human
#     your prompt is just one plain string
#     you are building a simple chain quickly
#
# example usage:
#     summarization
#     classification
#     rewriting
#     extraction
#     one-shot Q&A
#
# Use ChatPromptTemplate when
# ---------------------------
#     you want the prompt in chat-message format like system, human, assistant.
#     you are using a chat model
#     you want system instructions
#     you want separate human / AI / system messages
#     you want to include chat history later
#     you want better structure and control
#
# example usage:
#     assistants
#     conversation apps
#     role-based prompting
#     multi-message workflows
#     memory/chat-history use cases
# '''

# %% [markdown]
# # ********************************************
# # example 3.3
# # Example of ChatPromptTemplate with Parser
# # ********************************************

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

# %%
# Step 1: Define the prompt template
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful customer support assistant."),
    ("human", "Customer issue: {issue}")
])

# Step 2: Initialize LLM
# llm = ChatOpenAI(model="gpt-4o", temperature=0)

# Step 3: Create chain (new style)
chain = prompt | llm | StrOutputParser()

# Step 4: Invoke with input
response = chain.invoke({
    "issue": "My internet connection keeps disconnecting every 10 minutes."
})

# print(response.content)
print(response)

# %%
# **************************
# example 3.4 : JSON Parser
# **************************
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import JsonOutputParser
from langchain_openai import ChatOpenAI

# %%
# Step 1: Define parser with expected schema
parser = JsonOutputParser()
format_instructions = parser.get_format_instructions()

# Step 2: Create prompt template
prompt = ChatPromptTemplate.from_template("""
You are an AI assistant that classifies support tickets.

Extract the following fields:
- category
- priority
- suggested_action

{format_instructions}

User Query:
{query}
""")

# Step 3: Initialize LLM
llm = ChatOpenAI(model="gpt-4o", temperature=0)

# Step 4: Create chain
chain = prompt | llm | parser

# Step 5: Invoke
response = chain.invoke({
    "query": "My laptop is overheating and shutting down frequently.",
    "format_instructions": format_instructions
})

print(response)
# Out:
# {'category': 'Hardware Issue', 'priority': 'High', 'suggested_action': 'Check for dust in the vents, ensure proper ventilation, and consider seeking professional repair if the issue persists.'}

# %%
response
# Out:
# {'category': 'Hardware Issue',
#  'priority': 'High',
#  'suggested_action': 'Check for dust in the vents, ensure proper ventilation, and consider seeking professional repair if the issue persists.'}

# %%
# get the individual output key-values
cat = response['category']
priority = response['priority']
action = response['suggested_action']

print(action[:50])
# Out:
# Check for dust in the vents, ensure proper ventila

# %%
# *****************************
# example 3.5: Sequential Chain
# Sequential chains allow you to connect multiple chains and compose them into pipelines 
# that execute some specific scenario.
# Returns only the final response 
# *******************************

from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
# Step 1: Content
content_prompt = PromptTemplate( 
                input_variables=["title"],
                template="""You are an expert content writer.
                    Given a title, create a professional and high quality content with a suitable heading.
                    The content should not exceed 1000 words. 
                
                    Title: {title}
                
                    Content:""" 
                )

# Step 2: Summary
summary_prompt = PromptTemplate(
            input_variables=["contents"],
            template="""You are an expert editor of text documents.
                    Given the content on a topic, write a crisp 75-word summary. Retain the same heading.

                    Topic Content:
                    {contents}
                
                    Summary:"""
                )

parser = StrOutputParser()

# %%
# runnable chains
content_chain = content_prompt | llm | parser
summary_chain = summary_prompt | llm | parser

# full pipeline
chain = content_chain | (lambda contents: {"contents": contents}) | summary_chain

# %%
qry = "Should usage of mobile phones be restricted to children under 15 in India"

response = chain.invoke({"title": qry})
response
# Out:
# 'The debate on restricting mobile phone usage for children under 15 in India involves health, education, social development, and parental responsibility. Health concerns include screen-induced eye strain and disrupted sleep, while educational impacts involve distractions from studies. Socially, excessive phone use can lead to isolation and mental health issues. Parental guidance and digital literacy are crucial, suggesting a balanced approach with reasonable restrictions and education. This empowers children to use technology responsibly, maximizing benefits while minimizing risks.'

# %%
# ************* To return intermediate results *****************


# Method 1 - using 2 LLM calls (not an effective method)
# ------------------------------------------------------

from langchain_core.runnables import RunnableLambda

content_chain = content_prompt | llm | parser
summary_chain = summary_prompt | llm | parser

def workflow(inputs):
    contents = content_chain.invoke({"title": inputs["title"]})
    summary = summary_chain.invoke({"contents": contents})
    
    return {
        "title": inputs["title"],
        "contents": contents,
        "summary": summary
    }

chain = RunnableLambda(workflow)

response = chain.invoke({"title": "Social media impact on children"})

print("CONTENT:\n", response["contents"])
print("\nSUMMARY:\n", response["summary"])

# %%
# Method 2 - using 1 LLM call (more effective method)
# ------------------------------------------------------

from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import JsonOutputParser

combined_prompt = ChatPromptTemplate.from_template("""
You are a content writer.

For the given title:
1. Write detailed content in about 250 words.
2. Then write a short summary of that content in about 50 words.

Return the output strictly as JSON with these keys:
- contents
- summary

Title: {title}
""")

parser = JsonOutputParser()

chain = combined_prompt | llm | parser

response = chain.invoke({ "title": "Social media impact on children" })

# %%
print(len(response))
print(response.keys())
# Out:
# 2
# dict_keys(['contents', 'summary'])

# %%
# print the actual value of the key
print(response['contents'])
# Out:
# The impact of social media on children is a topic of growing concern among parents, educators, and mental health professionals. As digital natives, today's children are exposed to social media platforms from a young age, which can have both positive and negative effects on their development. On the positive side, social media can enhance communication skills, provide educational content, and foster a sense of community and belonging. Children can connect with peers who share similar interests, participate in collaborative projects, and access a wealth of information that can aid in their learning and personal growth.
#
# However, the negative impacts of social media on children cannot be overlooked. Excessive use of social media can lead to issues such as cyberbullying, exposure to inappropriate content, and a distorted sense of reality. The pressure to conform to unrealistic standards of beauty and success, often perpetuated by influencers and peers, can contribute to low self-esteem and mental health issues such as anxiety and depression. Additionally, the addictive nature of social media can lead to reduced physical activity, sleep disturbances, and impaired social skills as children may prefer virtual interactions over face-to-face communication.
#
# To mitigate these negative effects, it is crucial for parents and guardians to monitor their children's social media usage and engage in open discussions about online safety and digital literacy. Encouraging a balanced lifestyle that includes offline activities and fostering critical thinking skills can help children navigate the digital world more safely and responsibly.

# %%
print(response['summary'])
# Out:
# Social media impacts children both positively and negatively. It enhances communication and learning but can also lead to cyberbullying, low self-esteem, and addiction. Parents should monitor usage, promote online safety, and encourage a balanced lifestyle to help children navigate social media responsibly.

# %% [markdown]
# # =========================================================
# # 4) Component: Tools and Agents
# # Agent: Use LLMs to choose a specific activity to perform
# # Tool: Used by agents to perform a specific task
# # ========================================================

# %%
from langchain_core.tools import tool
from langchain_openai import ChatOpenAI

# %%
# Tool 1
@tool
def convert_degree_to_fahrenheit(celsius: float) -> float:
    """
    Convert temperature from Celsius to Fahrenheit.
    """
    return (celsius * 9/5) + 32


# Tool 2
@tool
def convert_fahrenheit_to_degree(fahrenheit: float) -> float:
    """
    Convert temperature from Fahrenheit to Celsius.
    """
    return (fahrenheit - 32) * 5/9

# %%
# Calling the tools directly
# Rare case

'''
c = 25
temp_f = convert_degree_to_fahrenheit.invoke({"celsius": c})
print(f"Celcius = {c}, Farenheit = {temp_f}")

f = 99
temp_c = convert_fahrenheit_to_degree.invoke({"fahrenheit": f})
print(f"Farenheit = {f}, Celcius = {temp_c}")
'''

# %%
llm = ChatOpenAI(model="gpt-4o")

# Register the tools
tools = [ convert_degree_to_fahrenheit, convert_fahrenheit_to_degree ]

llm_with_tools = llm.bind_tools(tools)

# %%
user_prompt = "convert 35 degrees C to F"

prompt = f''' You are an intelligent calculation agent who understands the input well and calls the correct tools.
             You have been given the following tools: {tools}

             Read the below user query well. 
             Select the right tool and automatically execute the user query using the tool name and parameters.
             Do not guess the tool name. If you cannot make out, return the response "No Tool Selected".

            User Prompt: {user_prompt}
'''

# %%
response = llm_with_tools.invoke(prompt)

# %%
tool_registry = {tool.name: tool for tool in tools }

tool_call = response.tool_calls
print(tool_call)

# %%
tool_name = tool_call[0]["name"]
tool_args = tool_call[0]["args"]

print(tool_name,tool_args)

# %%
result = tool_registry[tool_name].invoke(tool_args)

# %%
print(result)

# %%
# **************** NOTE ************************
# LLM decides the use of tools.
# if llm knows the answer, it will answer; else answer goes to the tool
# -----------------------------------------------------------------------------------

# %%
# pip install -U langchain langchain-openai langchain-community wikipedia


from langchain_community.tools import WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper
from langsmith import Client
from langchain.agents import create_agent
# from langchain.agents import create_react_agent, AgentExecutor

# %%
# %pip install wikipedia

# %%
p = "What is climate change"
pt = PromptTemplate.from_template(p)
prompt = pt.format()

# %%
# Tool
wiki = WikipediaQueryRun(api_wrapper=WikipediaAPIWrapper(top_k_results=1, doc_content_chars_max=1000) )
tools = [wiki]

# %%
agent = create_agent(model=llm, tools=tools, system_prompt="you are a helpful assistant")
content_msg = "What is climate change"
msg = {"messages": [{"role": "user", "content": content_msg}]}
response = agent.invoke(input=msg)

# %%
# (example 3) : 
# LLM + python functions as Tools
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
from langchain_community.tools import DuckDuckGoSearchRun
from langchain_core.tools import tool
from langchain_classic.agents import create_react_agent, AgentExecutor
import nltk
from nltk import word_tokenize, pos_tag, ne_chunk
# Out:
# C:\Users\sriraman.rajagopalan\AppData\Local\Temp\ipykernel_18412\1586070269.py:5: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.tools import DuckDuckGoSearchRun

# %%
llm = ChatOpenAI()

# %%
@tool
def extract_entities(text: str) -> dict:
    """Extract named entities and their types from the given input text."""
    entities = []

    tokens = word_tokenize(text)
    tagged = pos_tag(tokens)
    tree = ne_chunk(tagged)

    for subtree in tree:
        if hasattr(subtree, "label"):
            for token, pos in subtree:
                entities.append(f"{subtree.label()}:{token}")

    return {"entities": entities}

# %%
# pip install duckduckgo-search

search = DuckDuckGoSearchRun()
tools = [search, extract_entities]

# %%
# ReAct Prompt — all 4 variables are mandatory
template = """Answer the following questions as best you can. You have access to the following tools:

{tools}

Use the following format strictly:

Question: the input question you must answer
Thought: you should always think about what to do
Action: the action to take, should be one of [{tool_names}]
Action Input: the input to the action
Observation: the result of the action
Thought: I now know the final answer

Final Answer: Provide response in a JSON format as given below:
"text": <text>,  "entities": <list of extracted entities here> 

Begin!

Question: {input}
Thought:{agent_scratchpad}
"""

# %%
prompt = PromptTemplate.from_template(template)

# Create agent
agent = create_react_agent(llm=llm, tools=tools, prompt=prompt)

# %%
agent_executor = AgentExecutor(agent=agent, tools=tools, verbose=False,handle_parsing_errors=True, 
                               max_iterations=5, max_execution_time=30, return_intermediate_steps=True)

# %%
user_content = ''' Generate a 200-word text document on some of the best tourist destinations around the world. 
Include entities like country, state, city, people, year, currency etc. wherever possible.
From the generated text document, extract 10 entities and entity types and give in a tabular format
'''

# %%
result = agent_executor.invoke({"input": user_content})

# %%
result.keys()
# Out:
# dict_keys(['input', 'output', 'intermediate_steps'])

# %%
print(result['input'])
# Out:
#  Generate a 200-word text document on some of the best tourist destinations around the world.
# Include entities like country, state, city, people, year, currency etc. wherever possible.
# From the generated text document, extract 10 entities and entity types and give in a tabular format

# %%
output = result['output']

# %%
print(output)
# Out:
# {
# "text": "best tourist destinations around the world",
# "entities": [
# {"Spain": "Country"},
# {"Italy": "Country"},
# {"United States": "Country"},
# {"Peru": "Country"},
# {"Yosemite National Park": "Location"},
# {"Cortina": "Location"},
# {"Rome": "City"},
# {"Tokyo": "City"},
# {"Prague": "City"},
# {"Mauritius": "Country"}
# ]
# }

# %%
import re

# %%
output = re.sub("```", "",output)
output = re.sub("json\n","",output)
print(output)
# Out:
# {
# "text": "best tourist destinations around the world",
# "entities": [
# {"Spain": "Country"},
# {"Italy": "Country"},
# {"United States": "Country"},
# {"Peru": "Country"},
# {"Yosemite National Park": "Location"},
# {"Cortina": "Location"},
# {"Rome": "City"},
# {"Tokyo": "City"},
# {"Prague": "City"},
# {"Mauritius": "Country"}
# ]
# }

# %% [markdown]
# # Database as a Tool
# '''
# Flow:
# 1. User prompt
# 2. LLM selects one logical tool name
# 3. Python function executes matching SQL tool
# 4. LLM generates final analyst-style answer
# '''

# %%
import os
import mysql.connector
import pandas as pd
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
import pymysql

# %%
host = "localhost"; database="ey"; port=3306; user="root"; pwd="root"

# 1) Get MySQL Connection
# -----------------------
def get_mysql_conn():
    try:
        conn = mysql.connector.connect( host=host, port=port, database=database, user=user, password=pwd)
    except Exception as e:
        conn = str(e)

    return(conn)

# %%
conn = get_mysql_conn()

# %%
# Insert the response in the MySQL

def ExecuteQuery(action, query, values=None):
    ret = {"status": '', "message": "", "record": ""}
    act_msg = ''
    CURSOR = conn.cursor(dictionary=True)

    try:
        if action == "I":
            act_msg = "Inserted"
        elif action == "U":
            act_msg = "Updated"
        elif action == "D":
            act_msg = "Deleted"
        elif action == "S":
            act_msg = "Retrieved"

        if action in ["I", "U", "D"]:
            CURSOR.execute(query, values)
            conn.commit()
            ret["status"] = "SUCCESS"
            ret["message"] = f"{CURSOR.rowcount} Record(s) {act_msg}"
            ret["record"] = ''
        elif action == "S":
            if values is not None:
                CURSOR.execute(query, values)
            else:
                CURSOR.execute(query)

            data = CURSOR.fetchall()
            ret["status"] = "SUCCESS"
            ret["message"] = f"{len(data)} Record(s) {act_msg} "
            ret["record"] = pd.DataFrame(data)

    except Exception as e:
        ret["status"] = "EXCEPTION"
        ret["message"] = str(e)
        ret["record"] = ''
        CURSOR.close()

    finally:
        CURSOR.close()

    return (ret)

# %%
# 3. SQL Tool Definitions
# -----------------------------
def user_access_tool():
    query = """
    SELECT * FROM data_security  WHERE failed_logins_24h > 3 AND department = 'Risk';
    """
    return ExecuteQuery(action="S",query=query)

def risk_threat_scoring_tool():
    query = """
    SELECT department, AVG(risk_score) AS avg_risk FROM data_security GROUP BY department ORDER BY avg_risk DESC;
    """
    return ExecuteQuery(action="S",query=query)

def data_exfiltration_tool():
    query = """
    SELECT user_id, device_type, data_sensitivity_level
    FROM data_security
    WHERE data_sensitivity_level > 4;
    """
    return ExecuteQuery(query=query,action="S")

def device_endpoint_compliance_tool():
    query = """
    SELECT device_type, encryption_in_transit_flag, unmanaged_device_flag
    FROM data_security
    WHERE unmanaged_device_flag = 0;
    """
    return ExecuteQuery(query=query,action="S")

def fallback_sql_tool():
    query = """ SELECT * FROM data_security LIMIT 10; """
    return ExecuteQuery(query=query,action="S")

# %%
# ------------------- LLM -------------------
llm = ChatOpenAI(model="gpt-4o", temperature=0)

# %%
llm = ChatOpenAI(model="gpt-4o", temperature=0)

sys_prompt = """
You are a tool-selection agent for a BFSI data security dataset.

Choose exactly one tool from the following:

1. user_access
Use for:
- failed logins
- suspicious login behavior
- privileged users
- non-business hours access
- authentication issues

2. risk_threat_scoring
Use for:
- risk score
- threat score
- high-risk users
- department-wise risk
- average risk

3. data_exfiltration
Use for:
- DLP violations
- customer financial records
- data sensitivity
- data transfer
- data leakage
- exfiltration

4. device_endpoint_compliance
Use for:
- unmanaged devices
- endpoint compliance
- encryption
- non-compliant devices
- device security

Return only the tool name.
"""

# %%
select_tool_prompt = ChatPromptTemplate.from_messages([ ("system", sys_prompt), ("human", "{user_prompt}") ])

select_tool_chain = select_tool_prompt | llm | StrOutputParser()

# %%
user_prompt = "Show non-compliant endpoints connected to confidential banking resources." 

selected_tool = select_tool_chain.invoke({ "user_prompt": user_prompt})

selected_tool = selected_tool.strip().lower()

valid_tools = [ "user_access", "risk_threat_scoring", "data_exfiltration", "device_endpoint_compliance" ]

if selected_tool not in valid_tools:
    selected_tool = "fallback"

print(selected_tool)
# Out:
# device_endpoint_compliance

# %%
if selected_tool == "user_access":
    sql_result = user_access_tool()

elif selected_tool == "risk_threat_scoring":
    sql_result = risk_threat_scoring_tool()

elif selected_tool == "data_exfiltration":
    sql_result = data_exfiltration_tool()

elif selected_tool == "device_endpoint_compliance":
    sql_result = device_endpoint_compliance_tool()

else:
    sql_result = fallback_sql_tool()

status = sql_result
if status["status"] == "SUCCESS":
    print(status["record"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 11
#       7 elif selected_tool == "data_exfiltration":
#       8     sql_result = data_exfiltration_tool()
#       9
#      10 elif selected_tool == "device_endpoint_compliance":
# ---> 11     sql_result = device_endpoint_compliance_tool()
#      12
#      13 else:
#      14     sql_result = fallback_sql_tool()
#
# Cell In[24], line 29, in device_endpoint_compliance_tool()
#      25     SELECT device_type, encryption_in_transit_flag, unmanaged_device_flag
#      26     FROM data_security
#      27     WHERE unmanaged_device_flag = 0;
#      28     """
# ---> 29     return ExecuteQuery(query=query,action="S")
#
# Cell In[23], line 6, in ExecuteQuery(action, query, values)
#       3 def ExecuteQuery(action, query, values=None):
#       4     ret = {"status": '', "message": "", "record": ""}
#       5     act_msg = ''
# ----> 6     CURSOR = conn.cursor(dictionary=True)
#       7
#       8     try:
#       9         if action == "I":
#
# NameError: name 'conn' is not defined
